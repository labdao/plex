# %%
import os
import sys
import importlib

# this can disapear once plex is a pip package
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import plex.sdk
importlib.reload(plex.sdk)

os.environ["PLEX_ACCESS_TOKEN"] = "mellon"
os.environ["PLEX_ENV"] = "stage"

# %%
import csv
import os
import json

def create_pdbind_io_dict(csv_path):
    io_data = []
    
    with open(csv_path, 'r') as csvfile:
        csvreader = csv.DictReader(csvfile)
        
        for row in csvreader:
            protein_path = os.path.join("/home/ubuntu/", row['protein_path'])
            ligand_path = os.path.join("/home/ubuntu/", row['ligand_description'])
            
            if not os.path.exists(protein_path) or not os.path.exists(ligand_path):
                print(f"Skipping row {row['complex_name']} due to missing file(s).")
                continue
            
            entry = {
                "tool": "tools/equibind.json",
                "inputs": {
                    "protein": {
                        "class": "File",
                        "filepath": protein_path
                    },
                    "small_molecule": {
                        "class": "File",
                        "filepath": ligand_path
                    }
                },
                "outputs": {
                    "best_docked_small_molecule": {
                        "class": "File",
                        "filepath": ""
                    },
                    "protein": {
                        "class": "File",
                        "filepath": ""
                    }
                },
                "state": "created",
                "errMsg": ""
            }
            
            io_data.append(entry)
    
    return io_data

# Example usage
csv_path = '/home/ubuntu/datasets/diffdock_testdata.csv'
io_sig = create_pdbind_io_dict(csv_path)

# %%
from plex.sdk import run_plex

run_plex(io_sig, concurrency=2)
# Out:
# Plex version (v0.6.1) up to date.
# BACALHAU_API_HOST not set, using default host
# toolPath
# Running IPWL io path
# Created working directory:  /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a
# Reading IO Entries from:  /tmp/tmp5ws3tt5g/io_data.json
# Initialized IO file at:  /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/io.json
# Processing IO Entries
# /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a
# /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/io.json
# Starting to process IO entry 7
# Starting to process IO entry 3
# Job running...
# Bacalhau job id: 3ca90601-2bfb-40f0-82ae-6c0ab2eea9dc
# ////🌱____////
# Job running...
# Bacalhau job id: 6eaec00a-d692-40f0-b73a-00dc62c66b52
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-7/outputs/outputs/6hzb_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-7/outputs/6hzb_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-7/outputs/outputs/6hzb_protein_processed_6hzb_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-7/outputs/6hzb_protein_processed_6hzb_ligand_docked.sdfSuccess processing IO entry 7
# Starting to process IO entry 1
# Job running...
# Bacalhau job id: fc345824-f14e-4058-bf80-04b67e942369
# ////🌱____////
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-1/outputs/outputs/6d08_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-1/outputs/6d08_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-1/outputs/outputs/6d08_protein_processed_6d08_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-1/outputs/6d08_protein_processed_6d08_ligand_docked.sdfSuccess processing IO entry 1
# Starting to process IO entry 15
# Job running...
# Bacalhau job id: f673ee92-b686-4071-b3fe-930072384249
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-3/outputs/outputs/6np2_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-3/outputs/6np2_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-3/outputs/outputs/6np2_protein_processed_6np2_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-3/outputs/6np2_protein_processed_6np2_ligand_docked.sdfSuccess processing IO entry 3
# Starting to process IO entry 8
# Job running...
# Bacalhau job id: 36e41fe3-9993-4ff2-ad60-bb7324e00d8c
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-15/outputs/outputs/6g24_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-15/outputs/6g24_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-15/outputs/outputs/6g24_protein_processed_6g24_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-15/outputs/6g24_protein_processed_6g24_ligand_docked.sdfSuccess processing IO entry 15
# Starting to process IO entry 9
# Job running...
# Bacalhau job id: 0e4ece81-c131-4d02-a902-cbf9aaa9fd3b
# ////🌱____////
# ////___🌱_////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-8/outputs/outputs/6qrc_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-8/outputs/6qrc_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-8/outputs/outputs/6qrc_protein_processed_6qrc_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-8/outputs/6qrc_protein_processed_6qrc_ligand_docked.mol2Success processing IO entry 8
# Starting to process IO entry 10
# Job running...
# Bacalhau job id: b321336b-503d-4a85-ae2f-bd62d75b644f
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-9/outputs/outputs/6oio_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-9/outputs/6oio_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-9/outputs/outputs/6oio_protein_processed_6oio_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-9/outputs/6oio_protein_processed_6oio_ligand_docked.sdfSuccess processing IO entry 9
# Starting to process IO entry 11
# Job running...
# Bacalhau job id: dcc58dac-64f3-46e3-afe9-ab45882d1a8f
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-10/outputs/outputs/6jag_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-10/outputs/6jag_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-10/outputs/outputs/6jag_protein_processed_6jag_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-10/outputs/6jag_protein_processed_6jag_ligand_docked.sdfSuccess processing IO entry 10
# Starting to process IO entry 12
# Job running...
# Bacalhau job id: 978296b7-b609-4e9a-84de-23eafb2ccd70
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-11/outputs/outputs/6moa_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-11/outputs/6moa_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-11/outputs/outputs/6moa_protein_processed_6moa_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-11/outputs/6moa_protein_processed_6moa_ligand_docked.mol2Success processing IO entry 11
# Starting to process IO entry 0
# Job running...
# Bacalhau job id: ce79138e-6723-4c15-9c07-33f9752c1a66
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-12/outputs/outputs/6hld_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-12/outputs/6hld_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-12/outputs/outputs/6hld_protein_processed_6hld_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-12/outputs/6hld_protein_processed_6hld_ligand_docked.sdfSuccess processing IO entry 12
# Starting to process IO entry 13
# Job running...
# Bacalhau job id: 353d536f-cbe7-4a6f-a134-8dadf64fab0e
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-0/outputs/outputs/6qqw_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-0/outputs/6qqw_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-0/outputs/outputs/6qqw_protein_processed_6qqw_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-0/outputs/6qqw_protein_processed_6qqw_ligand_docked.mol2Success processing IO entry 0
# Starting to process IO entry 2
# Job running...
# Bacalhau job id: ab7befb0-95a6-4ef1-8255-94c4364e2c68
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-13/outputs/outputs/6i9a_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-13/outputs/6i9a_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-13/outputs/outputs/6i9a_protein_processed_6i9a_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-13/outputs/6i9a_protein_processed_6i9a_ligand_docked.sdfSuccess processing IO entry 13
# Starting to process IO entry 14
# Job running...
# Bacalhau job id: 7f7c9f3a-4a14-4279-a857-353940c09a0c
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-2/outputs/outputs/6jap_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-2/outputs/6jap_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-2/outputs/outputs/6jap_protein_processed_6jap_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-2/outputs/6jap_protein_processed_6jap_ligand_docked.sdfSuccess processing IO entry 2
# Starting to process IO entry 19
# Job running...
# Bacalhau job id: e708f8ba-4693-45b8-bbf2-61e18c22514a
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-14/outputs/outputs/6e4c_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-14/outputs/6e4c_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-14/outputs/outputs/6e4c_protein_processed_6e4c_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-14/outputs/6e4c_protein_processed_6e4c_ligand_docked.sdfSuccess processing IO entry 14
# Starting to process IO entry 16
# Job running...
# Bacalhau job id: 2caf322f-a393-4a0e-8f05-be8829e6967b
# ////🌱____////
# ////____🌱////
# ////_🌱___////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-19/outputs/outputs/6dyz_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-19/outputs/6dyz_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-19/outputs/outputs/6dyz_protein_processed_6dyz_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-19/outputs/6dyz_protein_processed_6dyz_ligand_docked.mol2Success processing IO entry 19
# Starting to process IO entry 17
# Job running...
# Bacalhau job id: ea85a3df-27a3-454d-b628-1e8c18f9828a
# ////🌱____////
# ////___🌱_////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-16/outputs/outputs/6jb4_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-16/outputs/6jb4_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-16/outputs/outputs/6jb4_protein_processed_6jb4_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-16/outputs/6jb4_protein_processed_6jb4_ligand_docked.sdfSuccess processing IO entry 16
# Starting to process IO entry 18
# Job running...
# Bacalhau job id: 3c1858d6-f68d-4d60-ab0b-05552732fd5c
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-17/outputs/outputs/6s55_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-17/outputs/6s55_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-17/outputs/outputs/6s55_protein_processed_6s55_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-17/outputs/6s55_protein_processed_6s55_ligand_docked.sdfSuccess processing IO entry 17
# Starting to process IO entry 5
# Job running...
# Bacalhau job id: 4d511532-86be-4abd-80a8-1474efb4ec3f
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-18/outputs/outputs/6seo_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-18/outputs/6seo_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-18/outputs/outputs/6seo_protein_processed_6seo_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-18/outputs/6seo_protein_processed_6seo_ligand_docked.sdfSuccess processing IO entry 18
# Starting to process IO entry 4
# Job running...
# Bacalhau job id: 1573dae1-4210-42cb-88a7-24585ad027e2
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-5/outputs/outputs/6oxq_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-5/outputs/6oxq_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-5/outputs/outputs/6oxq_protein_processed_6oxq_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-5/outputs/6oxq_protein_processed_6oxq_ligand_docked.sdfSuccess processing IO entry 5
# Starting to process IO entry 45
# Job running...
# Bacalhau job id: 37017363-c52b-4211-9297-b47552498acd
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-45/outputs/outputs/6cjs_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-45/outputs/6cjs_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-45/outputs/outputs/6cjs_protein_processed_6cjs_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-45/outputs/6cjs_protein_processed_6cjs_ligand_docked.sdfSuccess processing IO entry 45
# Starting to process IO entry 24
# Job running...
# Bacalhau job id: 372c5c77-d031-4439-b7f5-06d2ef3de224
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-4/outputs/outputs/6uvp_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-4/outputs/6uvp_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-4/outputs/outputs/6uvp_protein_processed_6uvp_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-4/outputs/6uvp_protein_processed_6uvp_ligand_docked.sdfSuccess processing IO entry 4
# Starting to process IO entry 25
# Job running...
# Bacalhau job id: 02152989-5341-4a39-8a9c-17d64cfe94bc
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-24/outputs/outputs/6a6k_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-24/outputs/6a6k_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-24/outputs/outputs/6a6k_protein_processed_6a6k_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-24/outputs/6a6k_protein_processed_6a6k_ligand_docked.sdfSuccess processing IO entry 24
# Starting to process IO entry 21
# Job running...
# Bacalhau job id: 44639e2a-f0d1-450c-b2a8-94a520cc0b2f
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-25/outputs/outputs/6qgf_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-25/outputs/6qgf_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-25/outputs/outputs/6qgf_protein_processed_6qgf_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-25/outputs/6qgf_protein_processed_6qgf_ligand_docked.sdfSuccess processing IO entry 25
# Starting to process IO entry 26
# Job running...
# Bacalhau job id: 86e5bfe6-c074-42fe-8029-516be04bafcf
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-21/outputs/outputs/6jid_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-21/outputs/6jid_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-21/outputs/outputs/6jid_protein_processed_6jid_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-21/outputs/6jid_protein_processed_6jid_ligand_docked.sdfSuccess processing IO entry 21
# Starting to process IO entry 58
# Job running...
# Bacalhau job id: bf2b38fb-3477-436f-9833-8b42d8223719
# ////🌱____////
# ////___🌱_////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-26/outputs/outputs/6e3z_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-26/outputs/6e3z_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-26/outputs/outputs/6e3z_protein_processed_6e3z_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-26/outputs/6e3z_protein_processed_6e3z_ligand_docked.sdfSuccess processing IO entry 26
# Starting to process IO entry 46
# Job running...
# Bacalhau job id: 4fd94a4f-4fb5-49a8-9441-6168626e68b1
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-58/outputs/outputs/6mo7_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-58/outputs/6mo7_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-58/outputs/outputs/6mo7_protein_processed_6mo7_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-58/outputs/6mo7_protein_processed_6mo7_ligand_docked.sdfSuccess processing IO entry 58
# Starting to process IO entry 47
# Job running...
# Bacalhau job id: 1545f5b4-b3aa-4c3f-98f8-a3dd6c040569
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# ////____🌱////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-46/outputs/outputs/6n9l_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-46/outputs/6n9l_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-46/outputs/outputs/6n9l_protein_processed_6n9l_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-46/outputs/6n9l_protein_processed_6n9l_ligand_docked.sdfSuccess processing IO entry 46
# Starting to process IO entry 48
# Job running...
# Bacalhau job id: d93d37c7-5f44-49c5-a383-571952872222
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-47/outputs/outputs/6ibz_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-47/outputs/6ibz_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-47/outputs/outputs/6ibz_protein_processed_6ibz_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-47/outputs/6ibz_protein_processed_6ibz_ligand_docked.sdfSuccess processing IO entry 47
# Starting to process IO entry 49
# Job running...
# Bacalhau job id: b2450632-cb2b-497d-8e84-5aabde943e7d
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# ////____🌱////
# ////____🌱////
# ////🌱____////
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-49/outputs/outputs/6gge_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-49/outputs/6gge_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-49/outputs/outputs/6gge_protein_processed_6gge_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-49/outputs/6gge_protein_processed_6gge_ligand_docked.sdfSuccess processing IO entry 49
# Starting to process IO entry 50
# Job running...
# Bacalhau job id: ae9a36f2-c59b-4bc7-8457-ac1f5b061b58
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-48/outputs/outputs/6ott_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-48/outputs/6ott_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-48/outputs/outputs/6ott_protein_processed_6ott_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-48/outputs/6ott_protein_processed_6ott_ligand_docked.sdfSuccess processing IO entry 48
# Starting to process IO entry 51
# Job running...
# Bacalhau job id: 2d93810f-4aa6-423b-b118-8e1b5395f6c5
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-50/outputs/outputs/6hot_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-50/outputs/6hot_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-50/outputs/outputs/6hot_protein_processed_6hot_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-50/outputs/6hot_protein_processed_6hot_ligand_docked.sdfSuccess processing IO entry 50
# Starting to process IO entry 52
# Job running...
# Bacalhau job id: 92448fe1-7358-462d-91cc-95d590b990ca
# ////🌱____////
# ////___🌱_////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-51/outputs/outputs/6e3p_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-51/outputs/6e3p_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-51/outputs/outputs/6e3p_protein_processed_6e3p_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-51/outputs/6e3p_protein_processed_6e3p_ligand_docked.mol2Success processing IO entry 51
# Starting to process IO entry 53
# Job running...
# Bacalhau job id: 6671e571-717d-4f7c-a5d1-5bab968ca4f1
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# ////____🌱////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-52/outputs/outputs/6md6_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-52/outputs/6md6_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-52/outputs/outputs/6md6_protein_processed_6md6_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-52/outputs/6md6_protein_processed_6md6_ligand_docked.sdfSuccess processing IO entry 52
# Starting to process IO entry 27
# Job running...
# Bacalhau job id: 0b0c9178-207c-44f6-be26-91ba2ce56afa
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-53/outputs/outputs/6hlb_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-53/outputs/6hlb_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-53/outputs/outputs/6hlb_protein_processed_6hlb_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-53/outputs/6hlb_protein_processed_6hlb_ligand_docked.sdfSuccess processing IO entry 53
# Starting to process IO entry 28
# Job running...
# Bacalhau job id: eaf0eb19-d363-4d61-9fa2-50ecb47746cf
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-27/outputs/outputs/6te6_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-27/outputs/6te6_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-27/outputs/outputs/6te6_protein_processed_6te6_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-27/outputs/6te6_protein_processed_6te6_ligand_docked.sdfSuccess processing IO entry 27
# Starting to process IO entry 54
# Job running...
# Bacalhau job id: cf29e9b6-c273-4dd0-8212-7f24d46a4c64
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-28/outputs/outputs/6pka_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-28/outputs/6pka_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-28/outputs/outputs/6pka_protein_processed_6pka_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-28/outputs/6pka_protein_processed_6pka_ligand_docked.sdfSuccess processing IO entry 28
# Starting to process IO entry 29
# Job running...
# Bacalhau job id: fb62e6e9-ed7c-42a9-833b-0759f5574a20
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////🌱____////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-29/outputs/outputs/6g2o_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-29/outputs/6g2o_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-29/outputs/outputs/6g2o_protein_processed_6g2o_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-29/outputs/6g2o_protein_processed_6g2o_ligand_docked.sdfSuccess processing IO entry 29
# Starting to process IO entry 30
# Job running...
# Bacalhau job id: 2ab85fe7-e911-44fc-b652-0a041d983163
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-54/outputs/outputs/6fe5_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-54/outputs/6fe5_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-54/outputs/outputs/6fe5_protein_processed_6fe5_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-54/outputs/6fe5_protein_processed_6fe5_ligand_docked.sdfSuccess processing IO entry 54
# Starting to process IO entry 31
# Job running...
# Bacalhau job id: b54463de-0986-4b60-b9ab-fe0a6f02f7c4
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-30/outputs/outputs/6jsf_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-30/outputs/6jsf_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-30/outputs/outputs/6jsf_protein_processed_6jsf_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-30/outputs/6jsf_protein_processed_6jsf_ligand_docked.sdfSuccess processing IO entry 30
# Starting to process IO entry 55
# Job running...
# Bacalhau job id: 54a90ec9-3162-48c8-8eb5-a16e7139cddc
# ////🌱____////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-31/outputs/outputs/5zxk_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-31/outputs/5zxk_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-31/outputs/outputs/5zxk_protein_processed_5zxk_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-31/outputs/5zxk_protein_processed_5zxk_ligand_docked.sdfSuccess processing IO entry 31
# Starting to process IO entry 32
# Job running...
# Bacalhau job id: 0e3ee020-bbfb-4ec2-b0d1-8f65ad08ace0
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-55/outputs/outputs/6uwp_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-55/outputs/6uwp_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-55/outputs/outputs/6uwp_protein_processed_6uwp_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-55/outputs/6uwp_protein_processed_6uwp_ligand_docked.sdfSuccess processing IO entry 55
# Starting to process IO entry 56
# Job running...
# Bacalhau job id: d737fb18-4222-4595-bb8f-234f650f6994
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-32/outputs/outputs/6qxd_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-32/outputs/6qxd_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-32/outputs/outputs/6qxd_protein_processed_6qxd_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-32/outputs/6qxd_protein_processed_6qxd_ligand_docked.sdfSuccess processing IO entry 32
# Starting to process IO entry 33
# Job running...
# Bacalhau job id: 9cda5b31-da9e-4941-9025-28bbbf152737
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-56/outputs/outputs/6npp_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-56/outputs/6npp_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-56/outputs/outputs/6npp_protein_processed_6npp_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-56/outputs/6npp_protein_processed_6npp_ligand_docked.sdf////___🌱_////
# Success processing IO entry 56
# Starting to process IO entry 57
# Job running...
# Bacalhau job id: b3bb6d33-22ef-4b7a-a021-eeeea6355cb3
# ////🌱____////
# ////____🌱////
# ////_🌱___////
# ////🌱____////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-57/outputs/outputs/6g2f_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-57/outputs/6g2f_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-57/outputs/outputs/6g2f_protein_processed_6g2f_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-57/outputs/6g2f_protein_processed_6g2f_ligand_docked.sdfSuccess processing IO entry 57
# Starting to process IO entry 34
# Job running...
# Bacalhau job id: 860fc139-d051-4aa8-a3a5-08478fbce3de
# ////🌱____////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-33/outputs/outputs/6n97_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-33/outputs/6n97_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-33/outputs/outputs/6n97_protein_processed_6n97_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-33/outputs/6n97_protein_processed_6n97_ligand_docked.sdfSuccess processing IO entry 33
# Starting to process IO entry 39
# Job running...
# Bacalhau job id: 1dbfa98e-f6f9-4787-983f-efd996e99c4b
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-34/outputs/outputs/6jt3_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-34/outputs/6jt3_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-34/outputs/outputs/6jt3_protein_processed_6jt3_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-34/outputs/6jt3_protein_processed_6jt3_ligand_docked.sdfSuccess processing IO entry 34
# Starting to process IO entry 40
# Job running...
# Bacalhau job id: 229fa1e6-97bf-4586-8b1d-aff8b6af380f
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-39/outputs/outputs/6qqz_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-39/outputs/6qqz_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-39/outputs/outputs/6qqz_protein_processed_6qqz_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-39/outputs/6qqz_protein_processed_6qqz_ligand_docked.mol2////_🌱___////
# Success processing IO entry 39
# Starting to process IO entry 35
# Job running...
# Bacalhau job id: 34c4d9a8-e16e-43ca-bc17-39a81de6dde4
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-40/outputs/outputs/6qmt_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-40/outputs/6qmt_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-40/outputs/outputs/6qmt_protein_processed_6qmt_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-40/outputs/6qmt_protein_processed_6qmt_ligand_docked.sdfSuccess processing IO entry 40
# Starting to process IO entry 41
# Job running...
# Bacalhau job id: d447ff39-d286-4870-92c2-19b3bbe56536
# ////🌱____////
# ////____🌱////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-35/outputs/outputs/6qtr_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-35/outputs/6qtr_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-35/outputs/outputs/6qtr_protein_processed_6qtr_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-35/outputs/6qtr_protein_processed_6qtr_ligand_docked.sdfSuccess processing IO entry 35
# Starting to process IO entry 42
# Job running...
# Bacalhau job id: 1af20a2d-26b6-4602-8dee-81983d68d96a
# ////🌱____////
# ////___🌱_////
# ////_🌱___////
# ////____🌱////
# ////__🌱__////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-41/outputs/outputs/6ibx_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-41/outputs/6ibx_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-41/outputs/outputs/6ibx_protein_processed_6ibx_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-41/outputs/6ibx_protein_processed_6ibx_ligand_docked.sdfSuccess processing IO entry 41
# Starting to process IO entry 36
# Job running...
# Bacalhau job id: 41a952e7-b383-47eb-957b-b5ba00008288
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-42/outputs/outputs/6hmt_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-42/outputs/6hmt_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-42/outputs/outputs/6hmt_protein_processed_6hmt_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-42/outputs/6hmt_protein_processed_6hmt_ligand_docked.sdfSuccess processing IO entry 42
# Starting to process IO entry 43
# Job running...
# Bacalhau job id: 28697976-057d-4d6b-adfe-78d57ee460c0
# ////🌱____////
# ////___🌱_////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# ////___🌱_////
# ////____🌱////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-36/outputs/outputs/6oy1_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-36/outputs/6oy1_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-36/outputs/outputs/6oy1_protein_processed_6oy1_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-36/outputs/6oy1_protein_processed_6oy1_ligand_docked.sdfSuccess processing IO entry 36
# Starting to process IO entry 37
# Job running...
# Bacalhau job id: 8fba4316-6778-4818-a032-e0e9f77e08f1
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
# ...
# ////_🌱___////
# ////__🌱__////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-345/outputs/outputs/6gj7_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-345/outputs/6gj7_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-345/outputs/outputs/6gj7_protein_processed_6gj7_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-345/outputs/6gj7_protein_processed_6gj7_ligand_docked.mol2Success processing IO entry 345
# Starting to process IO entry 347
# Job running...
# Bacalhau job id: eb53d246-dc00-4215-979a-ad6070fb5b41
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-346/outputs/outputs/6qr3_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-346/outputs/6qr3_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-346/outputs/outputs/6qr3_protein_processed_6qr3_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-346/outputs/6qr3_protein_processed_6qr3_ligand_docked.mol2Success processing IO entry 346
# Starting to process IO entry 348
# Job running...
# Bacalhau job id: 3e1cfc5a-1a9f-4d4a-99c4-4cdb6eba4181
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-347/outputs/outputs/6qr1_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-347/outputs/6qr1_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-347/outputs/outputs/6qr1_protein_processed_6qr1_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-347/outputs/6qr1_protein_processed_6qr1_ligand_docked.mol2Success processing IO entry 347
# Starting to process IO entry 362
# Job running...
# Bacalhau job id: 2254856e-77cb-40d1-8724-f59bf208a03f
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-348/outputs/outputs/6s9x_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-348/outputs/6s9x_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-348/outputs/outputs/6s9x_protein_processed_6s9x_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-348/outputs/6s9x_protein_processed_6s9x_ligand_docked.sdfSuccess processing IO entry 348
# Starting to process IO entry 349
# Job running...
# Bacalhau job id: 11bddd33-0abe-4e20-a96b-45a3332516b2
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-362/outputs/outputs/6mo2_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-362/outputs/6mo2_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-362/outputs/outputs/6mo2_protein_processed_6mo2_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-362/outputs/6mo2_protein_processed_6mo2_ligand_docked.mol2Success processing IO entry 362
# Starting to process IO entry 355
# Job running...
# Bacalhau job id: cb365555-c495-4944-b826-8026890ebfa8
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-349/outputs/outputs/6q4q_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-349/outputs/6q4q_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-349/outputs/outputs/6q4q_protein_processed_6q4q_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-349/outputs/6q4q_protein_processed_6q4q_ligand_docked.mol2Success processing IO entry 349
# Starting to process IO entry 350
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Job running...
# Bacalhau job id: 29ea75a2-48cd-4854-b8b6-93a1f17d1ba8
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-355/outputs/outputs/6t6a_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-355/outputs/6t6a_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-355/outputs/outputs/6t6a_protein_processed_6t6a_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-355/outputs/6t6a_protein_processed_6t6a_ligand_docked.mol2Success processing IO entry 355
# Starting to process IO entry 356
# Job running...
# Bacalhau job id: b81f0dfb-3d91-4532-85de-9a6637aa78bf
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-350/outputs/outputs/6hbn_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-350/outputs/6hbn_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-350/outputs/outputs/6hbn_protein_processed_6hbn_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-350/outputs/6hbn_protein_processed_6hbn_ligand_docked.sdfSuccess processing IO entry 350
# Starting to process IO entry 351
# Job running...
# Bacalhau job id: 04d0d7a7-5f19-4480-a68a-bb5f3512976b
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-356/outputs/outputs/6o5g_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-356/outputs/6o5g_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-356/outputs/outputs/6o5g_protein_processed_6o5g_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-356/outputs/6o5g_protein_processed_6o5g_ligand_docked.mol2Success processing IO entry 356
# Starting to process IO entry 352
# Job running...
# Bacalhau job id: 0f5b26a8-487d-43d9-af2c-daedc70c55f1
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-352/outputs/outputs/6tel_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-352/outputs/6tel_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-352/outputs/outputs/6tel_protein_processed_6tel_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-352/outputs/6tel_protein_processed_6tel_ligand_docked.sdfSuccess processing IO entry 352
# Starting to process IO entry 357
# Job running...
# Bacalhau job id: 7ff1f299-8f08-4755-a5af-60a1db7b6e43
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-351/outputs/outputs/6nw3_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-351/outputs/6nw3_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-351/outputs/outputs/6nw3_protein_processed_6nw3_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-351/outputs/6nw3_protein_processed_6nw3_ligand_docked.sdfSuccess processing IO entry 351
# Starting to process IO entry 353
# Job running...
# Bacalhau job id: 8d54b576-0597-4ea0-b307-89334910b881
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-357/outputs/outputs/6r7d_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-357/outputs/6r7d_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-357/outputs/outputs/6r7d_protein_processed_6r7d_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-357/outputs/6r7d_protein_processed_6r7d_ligand_docked.sdfSuccess processing IO entry 357
# Starting to process IO entry 354
# Job running...
# Bacalhau job id: d4a5771d-ccba-4666-8275-46014d9462a2
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-353/outputs/outputs/6p8y_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-353/outputs/6p8y_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-353/outputs/outputs/6p8y_protein_processed_6p8y_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-353/outputs/6p8y_protein_processed_6p8y_ligand_docked.sdfSuccess processing IO entry 353
# Starting to process IO entry 358
# Job running...
# Bacalhau job id: 039e37a5-a1c0-4f15-a5f0-f8b24e46cf91
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-354/outputs/outputs/6d5w_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-354/outputs/6d5w_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-354/outputs/outputs/6d5w_protein_processed_6d5w_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-354/outputs/6d5w_protein_processed_6d5w_ligand_docked.sdfSuccess processing IO entry 354
# Starting to process IO entry 360
# Job running...
# Bacalhau job id: dd9e2db9-719b-4e05-89ac-309e6c1460d1
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-358/outputs/outputs/6pya_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-358/outputs/6pya_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-358/outputs/outputs/6pya_protein_processed_6pya_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-358/outputs/6pya_protein_processed_6pya_ligand_docked.mol2Success processing IO entry 358
# Starting to process IO entry 359
# Job running...
# Bacalhau job id: 2d748ae1-2335-40d5-b29a-6697cf86b2e8
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-359/outputs/outputs/6ffe_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-359/outputs/6ffe_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-359/outputs/outputs/6ffe_protein_processed_6ffe_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-359/outputs/6ffe_protein_processed_6ffe_ligand_docked.sdfSuccess processing IO entry 359
# Starting to process IO entry 361
# Job running...
# Bacalhau job id: 9784015e-50ed-4395-93f0-4905ed45d09c
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-360/outputs/outputs/6d3x_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-360/outputs/6d3x_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-360/outputs/outputs/6d3x_protein_processed_6d3x_ligand_docked.sdf to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-360/outputs/6d3x_protein_processed_6d3x_ligand_docked.sdfSuccess processing IO entry 360
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Moving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-361/outputs/outputs/6gj8_protein_processed.pdb to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-361/outputs/6gj8_protein_processed.pdbMoving /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-361/outputs/outputs/6gj8_protein_processed_6gj8_ligand_docked.mol2 to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/entry-361/outputs/6gj8_protein_processed_6gj8_ligand_docked.mol2Success processing IO entry 361
# Finished processing, results written to /home/ubuntu/plex/4ce7171d-87c8-49ae-b728-cb480fded82a/io.json

# %%
# generating statistics on the success rate of the runs
import json
import pandas as pd

def get_state_counts(json_filepath):
    # Load the JSON data from the file
    with open(json_filepath, 'r') as f:
        data = json.load(f)
    
    # Extract the "state" and "errMsg" values from each JSON object
    state_errMsg_list = [{'state': item['state'], 'errMsg': item['errMsg']} for item in data]
    
    # Convert the list of dictionaries to a Pandas DataFrame
    df = pd.DataFrame(state_errMsg_list)
    
    # Count the occurrences of each unique "state" and "errMsg" combination
    counts_df = df.groupby(['state', 'errMsg']).size().reset_index(name='count')
    
    return counts_df, df

# Example usage
json_filepath = '/home/ubuntu/plex/0e1b24c5-870e-4a58-9b61-a302cecbbcd0/io.json'
state_counts_df, complete_df = get_state_counts(json_filepath)
print(state_counts_df)
# Out:
#         state                                             errMsg  count
# 0   completed                                                       289
# 1      failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 2      failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 3      failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 4      failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 5      failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 6      failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 7      failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 8      failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 9      failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 10     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 11     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 12     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 13     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 14     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 15     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 16     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 17     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 18     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 19     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 20     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 21     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 22     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 23     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 24     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 25     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...      1
# 26     failed  no output data found for: [best_docked_small_m...     49

# %%
complete_df[complete_df['state'] == 'failed']
# Out:
#       state                                             errMsg
# 0    failed  no output data found for: [best_docked_small_m...
# 8    failed  no output data found for: [best_docked_small_m...
# 11   failed  no output data found for: [best_docked_small_m...
# 19   failed  no output data found for: [best_docked_small_m...
# 39   failed  no output data found for: [best_docked_small_m...
# ..      ...                                                ...
# 355  failed  no output data found for: [best_docked_small_m...
# 356  failed  failed to write to '/home/ubuntu/plex/0e1b24c5...
# 358  failed  no output data found for: [best_docked_small_m...
# 361  failed  no output data found for: [best_docked_small_m...
# 362  failed  failed to write to '/home/ubuntu/plex/0e1b24c5...
#
# [74 rows x 2 columns]

# %%
def resubmit_failed_states(json_filepath):
    # Load the JSON data from the file
    with open(json_filepath, 'r') as f:
        data = json.load(f)
    
    # Filter the JSON list to include only entries with a failed state
    failed_entries = [entry for entry in data if entry['state'] == 'failed']
    
    # Create the io_sig object for each failed entry
    io_sig = []
    for entry in failed_entries:
        # Extract the relevant information from the JSON entry
        tool = entry['tool']
        inputs = entry['inputs']
        outputs = entry['outputs']
        state = 'created'  # Set the state to 'created' for resubmission
        errMsg = ''
        
        # Create a new entry for the io_sig object
        new_entry = {
            'tool': tool,
            'inputs': inputs,
            'outputs': outputs,
            'state': state,
            'errMsg': errMsg
        }
        
        # Append the new entry to the io_sig object
        io_sig.append(new_entry)
    
    return io_sig

# Example usage
json_filepath = '/home/ubuntu/plex/0e1b24c5-870e-4a58-9b61-a302cecbbcd0/io.json'
io_sig = resubmit_failed_states(json_filepath)

# %%
from plex.sdk import run_plex

run_plex(io_sig, concurrency=6)
# Out:
# Plex version (v0.6.1) up to date.
# BACALHAU_API_HOST not set, using default host
# toolPath
# Running IPWL io path
# Created job directory:  /home/ubuntu/plex/da5d8e24-e72f-4be6-ab14-f65b0cc6ec70
# Reading IO Entries from:  /tmp/tmp1a2k3gk6/io_data.json
# Initialized IO file at:  /home/ubuntu/plex/da5d8e24-e72f-4be6-ab14-f65b0cc6ec70/io.json
# Processing IO Entries
# Starting to process IO entry 7
# Starting to process IO entry 3
# Starting to process IO entry 0
# Starting to process IO entry 1
# Starting to process IO entry 19
# Starting to process IO entry 13
# Job running...
# ////🌱____////
# Job running...
# ////🌱____////
# Job running...
# ////🌱____////
# Job running...
# ////🌱____////
# Job running...
# Job running...
# ////🌱____////
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Success processing IO entry 7
# Starting to process IO entry 2
# Job running...
# ////🌱____////
# ////____🌱////
# ////____🌱////
# ////____🌱////
# ////____🌱////
# ////____🌱////
# ////_🌱___////
# ////🌱____////
# ////🌱____////
# ////🌱____////
# ////🌱____////
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////__🌱__////
# ////__🌱__////
# Success processing IO entry 13
# Starting to process IO entry 10
# Success processing IO entry 1
# Starting to process IO entry 8
# Success processing IO entry 3
# Starting to process IO entry 9
# Job running...
# ////🌱____////
# Job running...
# Job running...
# ////🌱____////
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Success processing IO entry 2
# Starting to process IO entry 16
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# Success processing IO entry 0
# Starting to process IO entry 14
# Job running...
# ////🌱____////
# Success processing IO entry 19
# Starting to process IO entry 17
# Job running...
# ////🌱____////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////_🌱___////
# ////_🌱___////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////__🌱__////
# ////__🌱__////
# ////____🌱////
# ////____🌱////
# ////____🌱////
# ////____🌱////
# ////___🌱_////
# ////___🌱_////
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Success processing IO entry 9
# Starting to process IO entry 18
# Job running...
# ////🌱____////
# ////____🌱////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# Success processing IO entry 16
# Starting to process IO entry 6
# Job running...
# ////🌱____////
# ////_🌱___////
# ////🌱____////
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# Success processing IO entry 10
# Starting to process IO entry 4
# Job running...
# ////🌱____////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# ////_🌱___////
# Success processing IO entry 14
# Starting to process IO entry 36
# Job running...
# ////🌱____////
# Success processing IO entry 17
# Starting to process IO entry 20
# Job running...
# ////🌱____////
# ////___🌱_////
# ////___🌱_////
# ////__🌱__////
# ////_🌱___////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# Success processing IO entry 18
# Starting to process IO entry 21
# Job running...
# ////🌱____////
# ////__🌱__////
# ////__🌱__////
# Success processing IO entry 6
# Starting to process IO entry 22
# Job running...
# ////🌱____////
# ////____🌱////
# ////_🌱___////
# ////___🌱_////
# ////___🌱_////
# ////_🌱___////
# ////🌱____////
# ////__🌱__////
# ////____🌱////
# ////____🌱////
# ////__🌱__////
# ////___🌱_////
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# Success processing IO entry 4
# Starting to process IO entry 23
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# ////_🌱___////
# Success processing IO entry 20
# Starting to process IO entry 24
# Job running...
# ////🌱____////
# ////🌱____////
# Success processing IO entry 36
# Starting to process IO entry 11
# Job running...
# ////🌱____////
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# Success processing IO entry 21
# Starting to process IO entry 51
# Job running...
# ////🌱____////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////___🌱_////
# ////_🌱___////
# ////🌱____////
# ////____🌱////
# Success processing IO entry 22
# Starting to process IO entry 73
# Job running...
# ////🌱____////
# ////____🌱////
# ////__🌱__////
# ////_🌱___////
# ////🌱____////
# ////_🌱___////
# ////🌱____////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Success processing IO entry 23
# Starting to process IO entry 52
# Job running...
# ////🌱____////
# ////__🌱__////
# Success processing IO entry 24
# Starting to process IO entry 53
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# Success processing IO entry 11
# Starting to process IO entry 54
# Job running...
# ////🌱____////
# ////_🌱___////
# ////___🌱_////
# ////_🌱___////
# ////🌱____////
# ////_🌱___////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# Success processing IO entry 73
# Starting to process IO entry 55
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# ////_🌱___////
# ////___🌱_////
# ////____🌱////
# Success processing IO entry 51
# Starting to process IO entry 56
# Job running...
# ////🌱____////
# ////____🌱////
# ////__🌱__////
# ////____🌱////
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////🌱____////
# ////_🌱___////
# Success processing IO entry 53
# Starting to process IO entry 57
# Job running...
# ////🌱____////
# ////__🌱__////
# ////____🌱////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Success processing IO entry 54
# Starting to process IO entry 43
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# Success processing IO entry 55
# Starting to process IO entry 58
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# Success processing IO entry 52
# Starting to process IO entry 44
# Job running...
# ////🌱____////
# Success processing IO entry 56
# Starting to process IO entry 45
# Job running...
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////____🌱////
# ////_🌱___////
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# ////🌱____////
# ////__🌱__////
# ////__🌱__////
# ////____🌱////
# ////___🌱_////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////🌱____////
# ////____🌱////
# ////____🌱////
# Success processing IO entry 57
# Starting to process IO entry 46
# Job running...
# ////🌱____////
# ////____🌱////
# ////_🌱___////
# ////🌱____////
# Success processing IO entry 8
# Starting to process IO entry 47
# Job running...
# ////🌱____////
# ////🌱____////
# ////_🌱___////
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# Success processing IO entry 43
# Starting to process IO entry 48
# ////_🌱___////
# Job running...
# ////🌱____////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# Success processing IO entry 58
# Starting to process IO entry 49
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////___🌱_////
# ////____🌱////
# Success processing IO entry 45
# Starting to process IO entry 50
# Job running...
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# ////___🌱_////
# ////__🌱__////
# Success processing IO entry 47
# Starting to process IO entry 66
# Job running...
# ////🌱____////
# ////__🌱__////
# ////____🌱////
# Success processing IO entry 44
# Starting to process IO entry 60
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////_🌱___////
# ////___🌱_////
# Success processing IO entry 46
# Starting to process IO entry 61
# ////_🌱___////
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# Success processing IO entry 48
# Starting to process IO entry 62
# Job running...
# ////🌱____////
# ////__🌱__////
# ////____🌱////
# ////_🌱___////
# ////__🌱__////
# ////🌱____////
# ////_🌱___////
# ////___🌱_////
# ////🌱____////
# ////__🌱__////
# ////___🌱_////
# ////_🌱___////
# ////__🌱__////
# ////____🌱////
# ////___🌱_////
# ////_🌱___////
# ////____🌱////
# ////__🌱__////
# ////___🌱_////
# ////🌱____////
# ////🌱____////
# ////__🌱__////
# ////____🌱////
# ////___🌱_////
# ////____🌱////
# ////_🌱___////
# ////_🌱___////
# ////___🌱_////
# ////🌱____////
# ////____🌱////
# ////🌱____////
# ////__🌱__////
# ////__🌱__////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# ////___🌱_////
# ////🌱____////
# ////___🌱_////
# ////__🌱__////
# ////_🌱___////
# Success processing IO entry 61
# Starting to process IO entry 63
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////_🌱___////
# Success processing IO entry 66
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Starting to process IO entry 64
# Job running...
# ////🌱____////
# Success processing IO entry 60
# Starting to process IO entry 65
# Job running...
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# Success processing IO entry 49
# Starting to process IO entry 40
# ////_🌱___////
# ////___🌱_////
# Job running...
# ////🌱____////
# Success processing IO entry 50
# Starting to process IO entry 38
# Job running...
# ////🌱____////
# ////__🌱__////
# ////__🌱__////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# ////_🌱___////
# ////___🌱_////
# ////___🌱_////
# ////🌱____////
# ////__🌱__////
# Success processing IO entry 62
# Starting to process IO entry 39
# Job running...
# ////🌱____////
# ////__🌱__////
# ////____🌱////
# ////____🌱////
# ////___🌱_////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////🌱____////
# ////🌱____////
# ////____🌱////
# ////__🌱__////
# ////____🌱////
# ////_🌱___////
# ////_🌱___////
# ////___🌱_////
# ////🌱____////
# ////🌱____////
# ////__🌱__////
# Success processing IO entry 63
# Starting to process IO entry 41
# Job running...
# ////🌱____////
# ////__🌱__////
# ////____🌱////
# ////_🌱___////
# ////_🌱___////
# ////___🌱_////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# Success processing IO entry 39
# Starting to process IO entry 69
# Success processing IO entry 65
# Starting to process IO entry 67
# Job running...
# ////🌱____////
# Job running...
# ////🌱____////
# Success processing IO entry 40
# Starting to process IO entry 68
# Success processing IO entry 38
# Starting to process IO entry 71
# Job running...
# ////🌱____////
# Job running...
# ////🌱____////
# Success processing IO entry 64
# Starting to process IO entry 70
# Job running...
# ////🌱____////
# ////____🌱////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////🌱____////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////____🌱////
# ////____🌱////
# ////____🌱////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# ////🌱____////
# ////🌱____////
# ////🌱____////
# ////🌱____////
# ////🌱____////
# Success processing IO entry 41
# Starting to process IO entry 30
# Job running...
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# Success processing IO entry 70
# Starting to process IO entry 25
# Job running...
# ////🌱____////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# ////_🌱___////
# Success processing IO entry 67
# Starting to process IO entry 31
# ////___🌱_////
# Job running...
# ////🌱____////
# ////____🌱////
# Success processing IO entry 68
# Starting to process IO entry 26
# Job running...
# ////🌱____////
# Success processing IO entry 69
# Starting to process IO entry 32
# Success processing IO entry 71
# Starting to process IO entry 27
# Job running...
# ////🌱____////
# Job running...
# ////🌱____////
# ////_🌱___////
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# ////____🌱////
# ////___🌱_////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# ////____🌱////
# ////🌱____////
# ////____🌱////
# ////🌱____////
# Success processing IO entry 25
# Starting to process IO entry 33
# Job running...
# ////🌱____////
# ////🌱____////
# ////_🌱___////
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////____🌱////
# Success processing IO entry 30
# Starting to process IO entry 28
# Job running...
# ////🌱____////
# Success processing IO entry 31
# Starting to process IO entry 34
# Job running...
# ////🌱____////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////__🌱__////
# ////__🌱__////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////___🌱_////
# ////___🌱_////
# ////__🌱__////
# Success processing IO entry 27
# Starting to process IO entry 29
# ////____🌱////
# Job running...
# ////🌱____////
# ////____🌱////
# Success processing IO entry 32
# Starting to process IO entry 35
# Job running...
# ////🌱____////
# Success processing IO entry 26
# Starting to process IO entry 42
# Job running...
# ////🌱____////
# ////🌱____////
# ////_🌱___////
# ////🌱____////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////_🌱___////
# ////_🌱___////
# ////__🌱__////
# ////_🌱___////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////___🌱_////
# ////____🌱////
# ////____🌱////
# ////____🌱////
# ////____🌱////
# ////🌱____////
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////🌱____////
# Success processing IO entry 33
# Starting to process IO entry 72
# Job running...
# ////🌱____////
# ////🌱____////
# ////_🌱___////
# ////_🌱___////
# Success processing IO entry 34
# Starting to process IO entry 12
# ////_🌱___////
# ////_🌱___////
# ////_🌱___////
# Job running...
# ////🌱____////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# ////___🌱_////
# ////__🌱__////
# ////___🌱_////
# ////____🌱////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# ////___🌱_////
# Success processing IO entry 42
# Starting to process IO entry 37
# Job running...
# ////____🌱////
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# ////🌱____////
# ////_🌱___////
# ////🌱____////
# ////__🌱__////
# ////_🌱___////
# ////___🌱_////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# ////__🌱__////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Success processing IO entry 28
# Starting to process IO entry 59
# Job running...
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Success processing IO entry 72
# Starting to process IO entry 5
# ////_🌱___////
# ////__🌱__////
# Job running...
# ////🌱____////
# ////___🌱_////
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# ////____🌱////
# ////__🌱__////
# ////___🌱_////
# Success processing IO entry 29
# Starting to process IO entry 15
# Job running...
# ////🌱____////
# Success processing IO entry 35
# Success processing IO entry 37
# ////_🌱___////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
#
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Success processing IO entry 12
# ////__🌱__////
# ////___🌱_////
# Success processing IO entry 5
# Success processing IO entry 59
# ////____🌱////
# ////🌱____////
# Computing default go-libp2p Resource Manager limits based on:
#     - 'Swarm.ResourceMgr.MaxMemory': "32 GB"
#     - 'Swarm.ResourceMgr.MaxFileDescriptors': 524288
#
# Applying any user-supplied overrides on top.
# Run 'ipfs swarm limit all' to see the resulting limits.
#
# Success processing IO entry 15
# Finished processing, results written to /home/ubuntu/plex/da5d8e24-e72f-4be6-ab14-f65b0cc6ec70/io.json

# %%
print(complete_df)
# Out:
#          state                                             errMsg
# 0       failed  no output data found for: [best_docked_small_m...
# 1    completed
# 2    completed
# 3    completed
# 4    completed
# ..         ...                                                ...
# 358     failed  no output data found for: [best_docked_small_m...
# 359  completed
# 360  completed
# 361     failed  no output data found for: [best_docked_small_m...
# 362     failed  failed to write to '/home/ubuntu/plex/0e1b24c5...
#
# [363 rows x 2 columns]

# %%
run_plex(io_sig, concurrency=6)
